# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set()
import  pandas as pd
import requests
from bs4 import BeautifulSoup
import csv

# %%
mostActiveStocksUrl = "https://www.nasdaq.com/markets/most-active.aspx"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
    "Accept-Encoding": "*",
    "Connection": "keep-alive"
} 
r= requests.get(mostActiveStocksUrl, headers=headers)
data=r.text
soup=BeautifulSoup(data)

# %%
table=soup.find_all('head')

# %% [markdown]
# ### ----------------[

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
data[0].head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# ...

# %%
data = pd.read_html('https://jakevdp.github.io/PythonDataScienceHandbook/03.12-performance-eval-and-query.html')
data
# Out:
# [   Unnamed: 0         A         B         C
#  0           0  0.375506  0.406939  0.069938
#  1           1  0.069087  0.235615  0.154374
#  2           2  0.677945  0.433839  0.652324
#  3           3  0.264038  0.808055  0.347197
#  4           4  0.589161  0.252418  0.557789,
#     Unnamed: 0         A         B         C
#  0           0  0.375506  0.406939  0.069938
#  1           1  0.069087  0.235615  0.154374
#  2           2  0.677945  0.433839  0.652324
#  3           3  0.264038  0.808055  0.347197
#  4           4  0.589161  0.252418  0.557789,
#     Unnamed: 0         A         B         C          D
#  0           0  0.375506  0.406939  0.069938  11.187620
#  1           1  0.069087  0.235615  0.154374   1.973796
#  2           2  0.677945  0.433839  0.652324   1.704344
#  3           3  0.264038  0.808055  0.347197   3.087857
#  4           4  0.589161  0.252418  0.557789   1.508776,
#     Unnamed: 0         A         B         C         D
# ...

# %%
mostActiveStocksUrl = 'https://www.advfn.com/nasdaq/nasdaq.asp'
r= requests.get(mostActiveStocksUrl)
data=r.text
soup=BeautifulSoup(data)

# %%
all_rows=soup.find_all('table')
all_rows
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" id="m" width="100%">
#  <tr>
#  <td align="left" width="22%"><img alt=" ADVFN - Advanced Financial Network. " height="60" src="/s/logo-flags.gif" usemap="#logoflags" width="189"/><br/>
#  <form action="/search.asp" id="cse-search-box" style="width:190px;text-align:left">
#  <div style="padding:2px 0 2px 2px">
#  <input name="cx" type="hidden" value="partner-pub-6249492958922688:voaf7tf1s08"/>
#  <input name="cof" type="hidden" value="FORID:11"/>
#  <input name="ie" type="hidden" value="UTF-8"/>
#  <input name="q" size="12" type="text"/>
#      <input name="sa" type="submit" value="Search"/>
#  </div>
#  </form>
#  </td>
#  <td id="ad1" width="53%">
#  <div class="dfpAd APS_TOP_BANNER_468_X_60" curpage="seo_site" id="APS_TOP_BANNER_468_X_60" page="apsglobalads" pos="1" view="gb"></div>
#  </td>
#  <td align="right" width="25%"></td>
#  </tr>
#  </table>,
#  <table cellpadding="0" cellspacing="0" id="newsalert-register">
#  <tr>
# ...

# %%
symbols=[]
names=[]
last_sales=[]
change_nets=[]
share_volumes=[]
 
for row in all_rows:
    cols=row.find_all('td')
cols[0]
# Out:
# <td align="center" colspan="2"><script language="javascript" src="/s/bookmarks.js"></script></td>

# %%
 
         
data=pd.DataFrame({'Names':names,'Last Sale': last_sales,'Chnange Net': change_nets,'Share Volume': share_volumes})
